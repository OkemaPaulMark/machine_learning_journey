# %%
#Tensorflow Lecture

# %%
#import the libraries 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential #type:ignore
from tensorflow.keras.layers import Dense  #type:ignore
from tensorflow.keras.callbacks import EarlyStopping #type:ignore
# Out:
# 2025-06-18 16:42:35.186890: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-18 16:42:35.187725: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-18 16:42:35.193297: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-18 16:42:35.207322: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750254155.230732  105169 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750254155.237598  105169 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750254155.255473  105169 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750254155.255501  105169 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750254155.255503  105169 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750254155.255505  105169 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-18 16:42:35.261727: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#load the dataset 
df = pd.read_csv('Churn.csv')
df.head()
# Out:
#   Customer ID  Gender  Senior Citizen Partner Dependents  tenure  \
# 0  7590-VHVEA  Female               0     Yes         No       1
# 1  7590-VHVEG  Female               0     Yes         No       1
# 2  5575-GNVDE    Male               0      No         No      34
# 3  3668-QPYBK    Male               0      No         No       2
# 4  7795-CFOCW    Male               0      No         No      45
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1            No  No phone service              DSL              No  ...
# 2           Yes                No              DSL             Yes  ...
# 3           Yes                No              DSL             Yes  ...
# 4            No  No phone service              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# 1                No           No           No               No
# 2               Yes           No           No               No
# 3                No           No           No               No
# 4               Yes          Yes           No               No
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes           Electronic check
# 1  Month-to-month               Yes           Electronic check
# 2        One year                No               Mailed check
# 3  Month-to-month               Yes               Mailed check
# 4        One year                No  Bank transfer (automatic)
#
#   Monthly Charges  Total Charges Churn
# 0           29.85          29.85    No
# 1           29.85          29.85    No
# 2           56.95         1889.5    No
# 3           53.85         108.15   Yes
# 4           42.30        1840.75    No
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7044 entries, 0 to 7043
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer ID        7044 non-null   object
#  1   Gender             7044 non-null   object
#  2   Senior Citizen     7044 non-null   int64
#  3   Partner            7044 non-null   object
#  4   Dependents         7044 non-null   object
#  5   tenure             7044 non-null   int64
#  6   Phone Service      7044 non-null   object
#  7   Multiple Lines     7044 non-null   object
#  8   Internet Service   7044 non-null   object
#  9   Online Security    7044 non-null   object
#  10  Online Backup      7044 non-null   object
#  11  Device Protection  7044 non-null   object
#  12  Tech Support       7044 non-null   object
#  13  Streaming TV       7044 non-null   object
#  14  Streaming Movies   7044 non-null   object
#  15  Contract           7044 non-null   object
#  16  Paperless Billing  7044 non-null   object
#  17  Payment Method     7044 non-null   object
#  18  Monthly Charges    7044 non-null   float64
#  19  Total Charges      7044 non-null   object
#  20  Churn              7044 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.drop(columns=['Customer ID'], inplace=True)
df['Total Charges'] = pd.to_numeric(df['Total Charges'], errors='coerce')
df.dropna(inplace=True)
df['Churn'] = df['Churn'].map({'No': 0, 'Yes': 1})

# %%
X = pd.get_dummies(df.drop('Churn', axis=1))
y = df['Churn']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print(X)
# Out:
#       Senior Citizen  tenure  Monthly Charges  Total Charges  Gender_Female  \
# 0                  0       1            29.85          29.85           True
# 1                  0       1            29.85          29.85           True
# 2                  0      34            56.95        1889.50          False
# 3                  0       2            53.85         108.15          False
# 4                  0      45            42.30        1840.75          False
# ...              ...     ...              ...            ...            ...
# 7039               0      24            84.80        1990.50          False
# 7040               0      72           103.20        7362.90           True
# 7041               0      11            29.60         346.45           True
# 7042               1       4            74.40         306.60          False
# 7043               0      66           105.65        6844.50          False
#
#       Gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 0           False       False         True           True           False
# 1           False       False         True           True           False
# 2            True        True        False           True           False
# 3            True        True        False           True           False
# 4            True        True        False           True           False
# ...           ...         ...          ...            ...             ...
# 7039         True       False         True          False            True
# 7040        False       False         True          False            True
# 7041        False       False         True          False            True
# 7042         True       False         True           True           False
# 7043         True        True        False           True           False
#
#       ...  Streaming Movies_Yes  Contract_Month-to-month  Contract_One year  \
# 0     ...                 False                     True              False
# 1     ...                 False                     True              False
# 2     ...                 False                    False               True
# 3     ...                 False                     True              False
# 4     ...                 False                    False               True
# ...   ...                   ...                      ...                ...
# 7039  ...                  True                    False               True
# 7040  ...                  True                    False               True
# 7041  ...                 False                     True              False
# 7042  ...                 False                     True              False
# 7043  ...                  True                    False              False
#
#       Contract_Two year  Paperless Billing_No  Paperless Billing_Yes  \
# 0                 False                 False                   True
# 1                 False                 False                   True
# 2                 False                  True                  False
# 3                 False                 False                   True
# 4                 False                  True                  False
# ...                 ...                   ...                    ...
# 7039              False                 False                   True
# 7040              False                 False                   True
# 7041              False                 False                   True
# 7042              False                 False                   True
# 7043               True                 False                   True
#
#       Payment Method_Bank transfer (automatic)  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                         True
# ...                                        ...
# 7039                                     False
# 7040                                     False
# 7041                                     False
# 7042                                     False
# 7043                                      True
#
#       Payment Method_Credit card (automatic)  Payment Method_Electronic check  \
# 0                                      False                             True
# 1                                      False                             True
# 2                                      False                            False
# 3                                      False                            False
# 4                                      False                            False
# ...                                      ...                              ...
# 7039                                   False                            False
# 7040                                    True                            False
# 7041                                   False                             True
# 7042                                   False                            False
# 7043                                   False                            False
#
#       Payment Method_Mailed check
# 0                           False
# 1                           False
# 2                            True
# 3                            True
# 4                           False
# ...                           ...
# 7039                         True
# 7040                        False
# 7041                        False
# 7042                         True
# 7043                        False
#
# [7033 rows x 45 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])
# Out:
# /home/okema-paul-mark/Documents/machine_learning/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-06-18 16:16:49.200062: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
early_stop = EarlyStopping(patience=3, restore_best_weights=True)

model.fit(X_train, y_train, validation_split=0.2, epochs=20,
          batch_size=32, callbacks=[early_stop])
# Out:
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7037 - loss: 0.5452 - val_accuracy: 0.7966 - val_loss: 0.4214
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8072 - loss: 0.4202 - val_accuracy: 0.8091 - val_loss: 0.4091
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8093 - loss: 0.4146 - val_accuracy: 0.8002 - val_loss: 0.4067
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8148 - loss: 0.3997 - val_accuracy: 0.8099 - val_loss: 0.4038
# Epoch 5/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8079 - loss: 0.4143 - val_accuracy: 0.8144 - val_loss: 0.4044
# Epoch 6/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8249 - loss: 0.3905 - val_accuracy: 0.8099 - val_loss: 0.4067
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8092 - loss: 0.3960 - val_accuracy: 0.8046 - val_loss: 0.4126

# %%
loss, acc = model.evaluate(X_test, y_test)
print(f"\nTest Accuracy: {acc:.2%}")
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7766 - loss: 0.4403
#
# Test Accuracy: 78.11%
